# %% [markdown]
# # Matplotlib Practice

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Plot a Python list
plt.plot([6,7,17,93]);

# %%
import numpy as np
import pandas as pd

# %%
# Create a bar graph using numpy, pandas, and matplotlib
x = np.random.rand(17,4)
x

#Create a data frame
df = pd.DataFrame(x, columns=['a', 'b','c', 'd'])
df
# Out:
#            a         b         c         d
# 0   0.586774  0.762230  0.659538  0.856356
# 1   0.854824  0.539424  0.913150  0.456205
# 2   0.552541  0.529447  0.077909  0.085906
# 3   0.358969  0.758993  0.970448  0.624652
# 4   0.588383  0.325302  0.672933  0.629770
# 5   0.398766  0.062310  0.614452  0.195651
# 6   0.219698  0.222741  0.251553  0.815474
# 7   0.741465  0.810071  0.351805  0.400590
# 8   0.734597  0.046180  0.041523  0.736441
# 9   0.191263  0.068627  0.474513  0.236499
# 10  0.615935  0.234797  0.790822  0.264062
# 11  0.398128  0.320555  0.122292  0.497969
# 12  0.524751  0.377414  0.876441  0.340043
# 13  0.540410  0.633708  0.468273  0.445455
# 14  0.139271  0.549365  0.038788  0.190579
# 15  0.169038  0.210774  0.291297  0.847904
# 16  0.352173  0.480870  0.690205  0.166343

# %%
df.plot.bar();
